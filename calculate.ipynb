# %%
import random
import math

# %%
n = 100
arr = [random.randint(1, 1000) for i in range(n)]
print(arr)
# Out:
# [540, 482, 651, 903, 219, 220, 304, 871, 307, 149, 58, 730, 617, 231, 835, 902, 511, 630, 981, 204, 26, 703, 729, 937, 288, 910, 364, 521, 865, 397, 289, 611, 488, 851, 460, 453, 241, 292, 545, 598, 829, 96, 458, 514, 375, 405, 255, 465, 511, 889, 820, 336, 547, 869, 347, 987, 998, 955, 556, 625, 113, 161, 647, 32, 922, 566, 452, 177, 341, 16, 406, 758, 341, 730, 264, 245, 835, 394, 106, 324, 391, 154, 239, 287, 428, 850, 55, 812, 524, 215, 436, 512, 469, 532, 124, 995, 305, 40, 411, 40]

# %%
mean = sum(arr) / n
print(mean)
# Out:
# 483.99

# %%
sortedArr = sorted(arr)
median = (sortedArr[n//2 - 1] + sortedArr[n//2]) / 2 if n%2==0 else sortedArr[n//2]
print(median)
# Out:
# 459.0

# %%
variance = sum((i - mean) ** 2 for i in arr) / (n - 1)
print(variance)

std = math.sqrt(variance)
print(std)
# Out:
# 76292.9796969697
# 276.21183844464326
